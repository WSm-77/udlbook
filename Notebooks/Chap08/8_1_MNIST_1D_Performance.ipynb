# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)

  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.569943, train error 61.35,  test loss 1.638209, test error 68.30
# Epoch     1, train loss 1.339123, train error 49.92,  test loss 1.481312, test error 58.10
# Epoch     2, train loss 1.204167, train error 44.58,  test loss 1.387049, test error 54.30
# Epoch     3, train loss 1.018626, train error 35.60,  test loss 1.247911, test error 49.70
# Epoch     4, train loss 0.931224, train error 33.03,  test loss 1.250880, test error 47.40
# Epoch     5, train loss 0.791419, train error 27.80,  test loss 1.118028, test error 43.40
# Epoch     6, train loss 0.730077, train error 26.40,  test loss 1.142254, test error 41.60
# Epoch     7, train loss 0.637366, train error 22.05,  test loss 1.062730, test error 39.30
# Epoch     8, train loss 0.631237, train error 22.60,  test loss 1.119426, test error 37.40
# Epoch     9, train loss 0.510063, train error 16.85,  test loss 1.044434, test error 39.90
# Epoch    10, train loss 0.415458, train error 11.68,  test loss 1.029456, test error 37.50
# Epoch    11, train loss 0.383584, train error 10.62,  test loss 1.074640, test error 38.50
# Epoch    12, train loss 0.347141, train error 10.00,  test loss 1.059226, test error 38.20
# Epoch    13, train loss 0.317666, train error 7.97,  test loss 1.080018, test error 38.20
# Epoch    14, train loss 0.284094, train error 6.38,  test loss 1.080701, test error 37.30
# Epoch    15, train loss 0.252396, train error 5.12,  test loss 1.084594, test error 37.20
# Epoch    16, train loss 0.233851, train error 4.62,  test loss 1.079669, test error 35.40
# Epoch    17, train loss 0.212638, train error 3.70,  test loss 1.134863, test error 37.40
# Epoch    18, train loss 0.193316, train error 2.72,  test loss 1.134475, test error 36.60
# Epoch    19, train loss 0.177124, train error 3.12,  test loss 1.159878, test error 36.70
# Epoch    20, train loss 0.152762, train error 2.07,  test loss 1.148658, test error 35.80
# Epoch    21, train loss 0.141745, train error 1.50,  test loss 1.162052, test error 36.00
# Epoch    22, train loss 0.133154, train error 1.20,  test loss 1.165930, test error 35.80
# Epoch    23, train loss 0.130217, train error 1.18,  test loss 1.188640, test error 37.00
# Epoch    24, train loss 0.119775, train error 0.85,  test loss 1.194888, test error 36.10
# Epoch    25, train loss 0.115230, train error 0.85,  test loss 1.207964, test error 35.70
# Epoch    26, train loss 0.108382, train error 0.57,  test loss 1.208461, test error 36.00
# Epoch    27, train loss 0.102757, train error 0.60,  test loss 1.227925, test error 35.80
# Epoch    28, train loss 0.099261, train error 0.53,  test loss 1.238828, test error 35.80
# Epoch    29, train loss 0.093457, train error 0.53,  test loss 1.237798, test error 37.00
# Epoch    30, train loss 0.088511, train error 0.32,  test loss 1.250302, test error 35.80
# Epoch    31, train loss 0.085515, train error 0.25,  test loss 1.253882, test error 35.20
# Epoch    32, train loss 0.083550, train error 0.18,  test loss 1.258010, test error 36.10
# Epoch    33, train loss 0.081563, train error 0.22,  test loss 1.265502, test error 35.80
# Epoch    34, train loss 0.079831, train error 0.22,  test loss 1.272171, test error 36.20
# Epoch    35, train loss 0.077723, train error 0.18,  test loss 1.278805, test error 36.30
# Epoch    36, train loss 0.075964, train error 0.18,  test loss 1.279085, test error 35.30
# Epoch    37, train loss 0.074427, train error 0.15,  test loss 1.289085, test error 36.20
# Epoch    38, train loss 0.073214, train error 0.18,  test loss 1.294610, test error 36.70
# Epoch    39, train loss 0.070912, train error 0.12,  test loss 1.295796, test error 36.20
# Epoch    40, train loss 0.069556, train error 0.10,  test loss 1.298325, test error 35.80
# Epoch    41, train loss 0.068750, train error 0.10,  test loss 1.302421, test error 35.50
# Epoch    42, train loss 0.068029, train error 0.10,  test loss 1.305777, test error 35.70
# Epoch    43, train loss 0.067150, train error 0.10,  test loss 1.307346, test error 35.70
# Epoch    44, train loss 0.066472, train error 0.10,  test loss 1.311462, test error 35.90
# Epoch    45, train loss 0.065770, train error 0.07,  test loss 1.316266, test error 35.70
# Epoch    46, train loss 0.065010, train error 0.07,  test loss 1.314553, test error 35.80
# Epoch    47, train loss 0.064379, train error 0.05,  test loss 1.316499, test error 36.10
# Epoch    48, train loss 0.063635, train error 0.05,  test loss 1.320412, test error 35.70
# Epoch    49, train loss 0.062990, train error 0.05,  test loss 1.322795, test error 36.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
D_i = 40    # Input dimensions
D_k = 150   # Hidden dimensions
D_o = 10    # Output dimensions

model2 = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)

  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

  print("Initializing layer")


# Call the function you just defined
model2.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=150, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=150, out_features=150, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=150, out_features=10, bias=True)
# )

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model2.parameters(), lr = 0.001, betas = (0.9, 0.999))
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

data_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

model2.apply(weights_init)

for epoch in range(n_epoch):
  for i, batch in enumerate(data_loader):
    x_batch, y_batch = batch
    pred = model2(x_batch)
    optimizer.zero_grad()
    loss = loss_function(pred, y_batch)
    loss.backward()
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model2(x_train)
  pred_test = model2(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.794483, train error 67.90,  test loss 1.861826, test error 71.60
# Epoch     1, train loss 1.590671, train error 60.67,  test loss 1.701040, test error 66.40
# Epoch     2, train loss 1.464778, train error 53.58,  test loss 1.621062, test error 63.10
# Epoch     3, train loss 1.366853, train error 49.08,  test loss 1.557402, test error 60.70
# Epoch     4, train loss 1.282109, train error 45.42,  test loss 1.502952, test error 56.70
# Epoch     5, train loss 1.197580, train error 40.80,  test loss 1.435117, test error 55.50
# Epoch     6, train loss 1.122175, train error 37.95,  test loss 1.406270, test error 53.70
# Epoch     7, train loss 1.055469, train error 34.25,  test loss 1.356532, test error 51.40
# Epoch     8, train loss 0.995194, train error 32.75,  test loss 1.332038, test error 51.50
# Epoch     9, train loss 0.931972, train error 29.88,  test loss 1.286096, test error 49.70
# Epoch    10, train loss 0.876042, train error 26.97,  test loss 1.256587, test error 47.50
# Epoch    11, train loss 0.836320, train error 26.18,  test loss 1.239259, test error 47.10
# Epoch    12, train loss 0.788379, train error 24.10,  test loss 1.231905, test error 45.90
# Epoch    13, train loss 0.762388, train error 24.18,  test loss 1.228724, test error 45.70
# Epoch    14, train loss 0.706572, train error 20.40,  test loss 1.190833, test error 46.00
# Epoch    15, train loss 0.662403, train error 19.47,  test loss 1.181806, test error 43.10
# Epoch    16, train loss 0.627746, train error 17.32,  test loss 1.166472, test error 44.10
# Epoch    17, train loss 0.600138, train error 16.82,  test loss 1.169606, test error 44.80
# Epoch    18, train loss 0.553520, train error 13.55,  test loss 1.139148, test error 42.60
# Epoch    19, train loss 0.526698, train error 13.90,  test loss 1.130603, test error 41.70
# Epoch    20, train loss 0.495736, train error 12.15,  test loss 1.135089, test error 42.40
# Epoch    21, train loss 0.469834, train error 11.32,  test loss 1.121286, test error 41.40
# Epoch    22, train loss 0.446544, train error 10.70,  test loss 1.123526, test error 41.60
# Epoch    23, train loss 0.423414, train error 10.30,  test loss 1.122520, test error 39.00
# Epoch    24, train loss 0.400493, train error 9.40,  test loss 1.137759, test error 41.10
# Epoch    25, train loss 0.383143, train error 8.88,  test loss 1.135380, test error 40.60
# Epoch    26, train loss 0.353311, train error 7.35,  test loss 1.146344, test error 41.00
# Epoch    27, train loss 0.333173, train error 6.65,  test loss 1.117941, test error 39.70
# Epoch    28, train loss 0.305428, train error 5.68,  test loss 1.112506, test error 38.30
# Epoch    29, train loss 0.286923, train error 4.65,  test loss 1.119762, test error 39.60
# Epoch    30, train loss 0.272771, train error 4.43,  test loss 1.135362, test error 40.30
# Epoch    31, train loss 0.255370, train error 3.90,  test loss 1.139051, test error 40.00
# Epoch    32, train loss 0.242754, train error 3.90,  test loss 1.135422, test error 39.10
# Epoch    33, train loss 0.225194, train error 3.15,  test loss 1.135767, test error 38.60
# Epoch    34, train loss 0.217076, train error 3.05,  test loss 1.166288, test error 39.40
# Epoch    35, train loss 0.203613, train error 2.90,  test loss 1.151010, test error 38.10
# Epoch    36, train loss 0.187559, train error 2.10,  test loss 1.157361, test error 38.70
# Epoch    37, train loss 0.169459, train error 1.38,  test loss 1.168637, test error 39.20
# Epoch    38, train loss 0.164803, train error 1.47,  test loss 1.173478, test error 37.90
# Epoch    39, train loss 0.151968, train error 1.12,  test loss 1.179260, test error 38.50
# Epoch    40, train loss 0.141021, train error 0.88,  test loss 1.190573, test error 38.30
# Epoch    41, train loss 0.129951, train error 0.75,  test loss 1.196614, test error 39.00
# Epoch    42, train loss 0.121296, train error 0.50,  test loss 1.202331, test error 38.30
# Epoch    43, train loss 0.114519, train error 0.55,  test loss 1.201486, test error 37.40
# Epoch    44, train loss 0.103300, train error 0.12,  test loss 1.225108, test error 38.70
# Epoch    45, train loss 0.098747, train error 0.20,  test loss 1.227818, test error 37.90
# Epoch    46, train loss 0.090369, train error 0.10,  test loss 1.233101, test error 37.70
# Epoch    47, train loss 0.085851, train error 0.12,  test loss 1.252890, test error 38.10
# Epoch    48, train loss 0.079927, train error 0.07,  test loss 1.261795, test error 37.40
# Epoch    49, train loss 0.071753, train error 0.03,  test loss 1.261755, test error 38.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

model3 = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)

  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

  print("Initializing layer")


# Call the function you just defined
model3.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model3.parameters(), lr = 0.001, betas = (0.9, 0.999))
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

data_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

model3.apply(weights_init)

for epoch in range(n_epoch):
  running_loss = 0.0
  running_correct = 0
  total = 0

  for i, batch in enumerate(data_loader):
    x_batch, y_batch = batch
    optimizer.zero_grad()
    pred = model3(x_batch)
    loss = loss_function(pred, y_batch)
    loss.backward()
    optimizer.step()

    # Batch statistics
    running_loss += loss.item() * x_batch.size(0)
    _, predicted = torch.max(pred.data, 1)
    running_correct += (predicted == y_batch).sum().item()
    total += x_batch.size(0)

  # Calculate average loss and error for this epoch (on batches)
  losses_train[epoch] = running_loss / total
  errors_train[epoch] = 100 - 100 * running_correct / total

  # Optionally, evaluate on test set as before
  pred_test = model3(x_test)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_test[epoch] = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_test[epoch] = loss_function(pred_test, y_test).item()

  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 2.432259, train error 83.83,  test loss 2.046414, test error 76.60
# Epoch     1, train loss 1.883421, train error 70.90,  test loss 1.833395, test error 71.40
# Epoch     2, train loss 1.703526, train error 65.20,  test loss 1.720670, test error 67.60
# Epoch     3, train loss 1.594888, train error 59.48,  test loss 1.645602, test error 65.30
# Epoch     4, train loss 1.516176, train error 56.10,  test loss 1.605814, test error 63.50
# Epoch     5, train loss 1.441417, train error 53.12,  test loss 1.539325, test error 60.70
# Epoch     6, train loss 1.371070, train error 48.80,  test loss 1.492870, test error 58.20
# Epoch     7, train loss 1.306837, train error 46.27,  test loss 1.446492, test error 55.10
# Epoch     8, train loss 1.242208, train error 43.12,  test loss 1.415584, test error 54.00
# Epoch     9, train loss 1.186533, train error 40.75,  test loss 1.382339, test error 52.30
# Epoch    10, train loss 1.136886, train error 39.12,  test loss 1.340989, test error 52.50
# Epoch    11, train loss 1.086806, train error 36.88,  test loss 1.311874, test error 49.70
# Epoch    12, train loss 1.042668, train error 35.55,  test loss 1.306100, test error 49.20
# Epoch    13, train loss 1.002543, train error 33.78,  test loss 1.265087, test error 48.40
# Epoch    14, train loss 0.966636, train error 32.40,  test loss 1.262327, test error 48.70
# Epoch    15, train loss 0.934440, train error 31.50,  test loss 1.237892, test error 46.90
# Epoch    16, train loss 0.902506, train error 30.12,  test loss 1.227042, test error 44.80
# Epoch    17, train loss 0.875569, train error 29.47,  test loss 1.220483, test error 46.30
# Epoch    18, train loss 0.846624, train error 28.40,  test loss 1.207019, test error 46.70
# Epoch    19, train loss 0.815014, train error 27.17,  test loss 1.185551, test error 44.90
# Epoch    20, train loss 0.792350, train error 26.50,  test loss 1.184905, test error 45.20
# Epoch    21, train loss 0.768169, train error 26.05,  test loss 1.181674, test error 45.10
# Epoch    22, train loss 0.743239, train error 24.30,  test loss 1.184888, test error 44.80
# Epoch    23, train loss 0.722150, train error 23.75,  test loss 1.177265, test error 45.80
# Epoch    24, train loss 0.698685, train error 22.88,  test loss 1.176854, test error 44.30
# Epoch    25, train loss 0.682475, train error 22.35,  test loss 1.167130, test error 43.00
# Epoch    26, train loss 0.663836, train error 22.22,  test loss 1.143770, test error 43.60
# Epoch    27, train loss 0.634777, train error 20.25,  test loss 1.158874, test error 44.00
# Epoch    28, train loss 0.621264, train error 19.70,  test loss 1.171494, test error 43.90
# Epoch    29, train loss 0.601941, train error 18.85,  test loss 1.160066, test error 43.70
# Epoch    30, train loss 0.584663, train error 17.88,  test loss 1.144369, test error 43.00
# Epoch    31, train loss 0.568710, train error 17.85,  test loss 1.151949, test error 43.40
# Epoch    32, train loss 0.547881, train error 17.00,  test loss 1.151291, test error 41.80
# Epoch    33, train loss 0.532533, train error 16.17,  test loss 1.159685, test error 42.60
# Epoch    34, train loss 0.520328, train error 15.45,  test loss 1.153736, test error 42.50
# Epoch    35, train loss 0.503719, train error 14.88,  test loss 1.164470, test error 42.70
# Epoch    36, train loss 0.489531, train error 15.05,  test loss 1.155919, test error 42.40
# Epoch    37, train loss 0.473738, train error 13.78,  test loss 1.161215, test error 42.70
# Epoch    38, train loss 0.456202, train error 13.05,  test loss 1.160768, test error 42.70
# Epoch    39, train loss 0.443074, train error 13.00,  test loss 1.157981, test error 42.00
# Epoch    40, train loss 0.428046, train error 12.00,  test loss 1.171788, test error 42.00
# Epoch    41, train loss 0.418010, train error 11.67,  test loss 1.174296, test error 42.00
# Epoch    42, train loss 0.405563, train error 11.55,  test loss 1.189619, test error 42.60
# Epoch    43, train loss 0.394511, train error 11.08,  test loss 1.179263, test error 41.00
# Epoch    44, train loss 0.384164, train error 11.05,  test loss 1.182651, test error 41.30
# Epoch    45, train loss 0.365532, train error 9.62,  test loss 1.184433, test error 41.30
# Epoch    46, train loss 0.350456, train error 8.97,  test loss 1.189405, test error 41.10
# Epoch    47, train loss 0.340874, train error 8.55,  test loss 1.213089, test error 41.60
# Epoch    48, train loss 0.329449, train error 8.47,  test loss 1.202542, test error 40.40
# Epoch    49, train loss 0.322072, train error 8.25,  test loss 1.225215, test error 40.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

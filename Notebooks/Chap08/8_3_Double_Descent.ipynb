# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # x_train = torch.tensor(data['x'].astype('float32')).to(DEVICE)
  # y_train = torch.tensor(data['y'].transpose().astype('long')).to(DEVICE)
  # x_test= torch.tensor(data['x_test'].astype('float32')).to(DEVICE)
  # y_test = torch.tensor(data['y_test'].astype('long')).to(DEVICE)
  # model.to(DEVICE)

  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))


  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # x_batch = x_batch.to(DEVICE)
      # y_batch = y_batch.to(DEVICE)

      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# ##### Predictions:
#
# 1. $ \sqrt{4000} \approx 64 $ - when number of parameters equals number of training examples
# 2. $ 40 $ - slightli before double descent curve maximum
# 3. $ \sqrt{4000} \approx 64 $ - when number of parameters equals number of training examples

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303923, train error 90.50,  test loss 2.304590, test error 91.18
# Epoch   100, train loss 1.925858, train error 71.85,  test loss 1.778339, test error 69.80
# Epoch   200, train loss 1.909992, train error 71.00,  test loss 1.747299, test error 68.95
# Epoch   300, train loss 1.904454, train error 71.15,  test loss 1.749740, test error 68.97
# Epoch   400, train loss 1.899407, train error 71.05,  test loss 1.732515, test error 68.88
# Epoch   500, train loss 1.894175, train error 70.75,  test loss 1.729614, test error 68.12
# Epoch   600, train loss 1.867808, train error 70.28,  test loss 1.692795, test error 68.45
# Epoch   700, train loss 1.868453, train error 70.72,  test loss 1.716506, test error 68.93
# Epoch   800, train loss 1.864472, train error 71.38,  test loss 1.711900, test error 68.70
# Epoch   900, train loss 1.861540, train error 70.28,  test loss 1.709735, test error 67.90
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302275, train error 89.90,  test loss 2.300236, test error 89.43
# Epoch   100, train loss 1.771540, train error 66.95,  test loss 1.635091, test error 64.45
# Epoch   200, train loss 1.747727, train error 65.03,  test loss 1.596964, test error 62.10
# Epoch   300, train loss 1.758708, train error 65.20,  test loss 1.607714, test error 63.15
# Epoch   400, train loss 1.743156, train error 64.93,  test loss 1.593197, test error 61.83
# Epoch   500, train loss 1.741136, train error 64.07,  test loss 1.593376, test error 61.38
# Epoch   600, train loss 1.738690, train error 63.92,  test loss 1.585979, test error 61.00
# Epoch   700, train loss 1.737789, train error 64.47,  test loss 1.572115, test error 61.35
# Epoch   800, train loss 1.726663, train error 63.45,  test loss 1.572592, test error 60.72
# Epoch   900, train loss 1.728667, train error 63.12,  test loss 1.558746, test error 60.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.286450, train error 89.65,  test loss 2.282064, test error 90.03
# Epoch   100, train loss 1.694961, train error 60.38,  test loss 1.530044, test error 59.53
# Epoch   200, train loss 1.649309, train error 59.22,  test loss 1.499513, test error 58.47
# Epoch   300, train loss 1.619930, train error 58.12,  test loss 1.479112, test error 56.65
# Epoch   400, train loss 1.610097, train error 58.05,  test loss 1.479035, test error 57.42
# Epoch   500, train loss 1.586868, train error 57.30,  test loss 1.459659, test error 56.62
# Epoch   600, train loss 1.605499, train error 58.00,  test loss 1.470510, test error 55.83
# Epoch   700, train loss 1.579694, train error 57.05,  test loss 1.462115, test error 55.80
# Epoch   800, train loss 1.574593, train error 56.83,  test loss 1.456211, test error 55.35
# Epoch   900, train loss 1.581030, train error 56.88,  test loss 1.472427, test error 55.72
# Training model with   8 hidden variables
# Epoch     0, train loss 2.274195, train error 86.32,  test loss 2.263743, test error 85.70
# Epoch   100, train loss 1.550109, train error 54.08,  test loss 1.380471, test error 51.70
# Epoch   200, train loss 1.460927, train error 49.15,  test loss 1.272777, test error 47.70
# Epoch   300, train loss 1.439077, train error 48.25,  test loss 1.271285, test error 46.53
# Epoch   400, train loss 1.434828, train error 48.03,  test loss 1.272180, test error 46.83
# Epoch   500, train loss 1.429879, train error 47.60,  test loss 1.269500, test error 46.60
# Epoch   600, train loss 1.426129, train error 47.40,  test loss 1.267056, test error 46.62
# Epoch   700, train loss 1.425444, train error 47.90,  test loss 1.278098, test error 46.67
# Epoch   800, train loss 1.420803, train error 47.97,  test loss 1.275201, test error 46.30
# Epoch   900, train loss 1.425096, train error 48.05,  test loss 1.277708, test error 46.47
# Training model with  10 hidden variables
# Epoch     0, train loss 2.254378, train error 85.95,  test loss 2.245290, test error 84.60
# Epoch   100, train loss 1.612307, train error 56.03,  test loss 1.478777, test error 56.22
# Epoch   200, train loss 1.568110, train error 54.40,  test loss 1.490385, test error 56.72
# Epoch   300, train loss 1.524725, train error 53.10,  test loss 1.476246, test error 55.53
# Epoch   400, train loss 1.511043, train error 52.60,  test loss 1.479823, test error 55.75
# Epoch   500, train loss 1.499177, train error 51.75,  test loss 1.487061, test error 56.00
# Epoch   600, train loss 1.492270, train error 52.20,  test loss 1.493391, test error 55.88
# Epoch   700, train loss 1.495802, train error 52.33,  test loss 1.495218, test error 56.30
# Epoch   800, train loss 1.482927, train error 51.85,  test loss 1.497566, test error 56.40
# Epoch   900, train loss 1.478647, train error 50.85,  test loss 1.486443, test error 55.40
# Training model with  14 hidden variables
# Epoch     0, train loss 2.137158, train error 81.12,  test loss 2.089195, test error 78.65
# Epoch   100, train loss 1.481561, train error 50.83,  test loss 1.419452, test error 54.40
# Epoch   200, train loss 1.374526, train error 48.10,  test loss 1.387351, test error 52.17
# Epoch   300, train loss 1.345786, train error 46.45,  test loss 1.403783, test error 52.10
# Epoch   400, train loss 1.329125, train error 45.47,  test loss 1.403998, test error 51.42
# Epoch   500, train loss 1.314886, train error 44.65,  test loss 1.422725, test error 52.30
# Epoch   600, train loss 1.296902, train error 44.62,  test loss 1.427566, test error 51.70
# Epoch   700, train loss 1.288840, train error 44.95,  test loss 1.451841, test error 51.58
# Epoch   800, train loss 1.279624, train error 44.45,  test loss 1.466266, test error 51.70
# Epoch   900, train loss 1.275583, train error 44.00,  test loss 1.487525, test error 51.97
# Training model with  18 hidden variables
# Epoch     0, train loss 2.255858, train error 83.47,  test loss 2.247037, test error 82.60
# Epoch   100, train loss 1.348721, train error 45.15,  test loss 1.329992, test error 49.78
# Epoch   200, train loss 1.242201, train error 41.28,  test loss 1.329658, test error 49.50
# Epoch   300, train loss 1.215504, train error 40.78,  test loss 1.381696, test error 49.62
# Epoch   400, train loss 1.188676, train error 39.28,  test loss 1.426096, test error 50.35
# Epoch   500, train loss 1.169601, train error 38.85,  test loss 1.439038, test error 50.67
# Epoch   600, train loss 1.167817, train error 39.33,  test loss 1.480337, test error 51.38
# Epoch   700, train loss 1.146320, train error 38.55,  test loss 1.475754, test error 51.45
# Epoch   800, train loss 1.144280, train error 39.12,  test loss 1.498305, test error 51.42
# Epoch   900, train loss 1.130169, train error 38.55,  test loss 1.501320, test error 52.12
# Training model with  22 hidden variables
# Epoch     0, train loss 2.114292, train error 78.35,  test loss 2.067438, test error 78.43
# Epoch   100, train loss 1.253291, train error 41.67,  test loss 1.307688, test error 48.75
# Epoch   200, train loss 1.143553, train error 38.05,  test loss 1.372100, test error 49.62
# Epoch   300, train loss 1.085222, train error 36.78,  test loss 1.434783, test error 49.83
# Epoch   400, train loss 1.049228, train error 35.82,  test loss 1.494601, test error 50.40
# Epoch   500, train loss 1.022250, train error 34.82,  test loss 1.560053, test error 51.75
# Epoch   600, train loss 1.010551, train error 34.80,  test loss 1.592275, test error 51.33
# Epoch   700, train loss 1.001542, train error 34.62,  test loss 1.648240, test error 52.45
# Epoch   800, train loss 0.983982, train error 33.45,  test loss 1.677119, test error 52.28
# Epoch   900, train loss 0.979738, train error 33.88,  test loss 1.699713, test error 53.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.201857, train error 82.00,  test loss 2.200502, test error 81.97
# Epoch   100, train loss 1.211788, train error 40.97,  test loss 1.406744, test error 50.80
# Epoch   200, train loss 1.065247, train error 36.50,  test loss 1.531670, test error 52.12
# Epoch   300, train loss 0.995260, train error 33.18,  test loss 1.606652, test error 52.25
# Epoch   400, train loss 0.966301, train error 31.55,  test loss 1.707189, test error 52.50
# Epoch   500, train loss 0.934842, train error 31.10,  test loss 1.799247, test error 53.40
# Epoch   600, train loss 0.914547, train error 30.82,  test loss 1.875080, test error 54.30
# Epoch   700, train loss 0.901531, train error 29.80,  test loss 1.966037, test error 55.30
# Epoch   800, train loss 0.895858, train error 29.88,  test loss 2.009523, test error 56.00
# Epoch   900, train loss 0.866356, train error 29.05,  test loss 2.086799, test error 56.33
# Training model with  30 hidden variables
# Epoch     0, train loss 2.173781, train error 80.50,  test loss 2.140751, test error 80.18
# Epoch   100, train loss 1.130459, train error 37.30,  test loss 1.361233, test error 50.05
# Epoch   200, train loss 0.947508, train error 30.78,  test loss 1.541943, test error 52.38
# Epoch   300, train loss 0.867176, train error 28.55,  test loss 1.751125, test error 53.25
# Epoch   400, train loss 0.810869, train error 27.18,  test loss 1.905891, test error 54.30
# Epoch   500, train loss 0.778153, train error 26.45,  test loss 2.004494, test error 53.78
# Epoch   600, train loss 0.758228, train error 26.10,  test loss 2.148717, test error 54.50
# Epoch   700, train loss 0.736602, train error 25.60,  test loss 2.249818, test error 54.08
# Epoch   800, train loss 0.702888, train error 23.55,  test loss 2.409549, test error 55.15
# Epoch   900, train loss 0.698977, train error 24.15,  test loss 2.572363, test error 56.38
# Training model with  35 hidden variables
# Epoch     0, train loss 2.153515, train error 78.85,  test loss 2.135088, test error 78.97
# Epoch   100, train loss 1.000652, train error 33.47,  test loss 1.418536, test error 50.65
# Epoch   200, train loss 0.795486, train error 27.35,  test loss 1.730523, test error 53.10
# Epoch   300, train loss 0.671145, train error 21.57,  test loss 2.041577, test error 54.12
# Epoch   400, train loss 0.606897, train error 20.18,  test loss 2.382863, test error 54.85
# Epoch   500, train loss 0.568385, train error 19.12,  test loss 2.743872, test error 55.17
# Epoch   600, train loss 0.524454, train error 18.07,  test loss 3.021105, test error 56.55
# Epoch   700, train loss 0.515800, train error 17.82,  test loss 3.338815, test error 56.28
# Epoch   800, train loss 0.469634, train error 16.07,  test loss 3.585639, test error 56.90
# Epoch   900, train loss 0.475736, train error 16.68,  test loss 3.891376, test error 57.15
# Training model with  40 hidden variables
# Epoch     0, train loss 2.161360, train error 79.60,  test loss 2.139930, test error 80.47
# Epoch   100, train loss 0.941105, train error 29.68,  test loss 1.392870, test error 48.95
# Epoch   200, train loss 0.618016, train error 19.07,  test loss 1.907902, test error 52.15
# Epoch   300, train loss 0.474159, train error 15.05,  test loss 2.565801, test error 54.03
# Epoch   400, train loss 0.387401, train error 12.53,  test loss 3.412526, test error 56.75
# Epoch   500, train loss 0.313759, train error 10.12,  test loss 4.171713, test error 56.67
# Epoch   600, train loss 0.259650, train error 8.62,  test loss 4.988533, test error 56.62
# Epoch   700, train loss 0.251447, train error 8.80,  test loss 5.815297, test error 57.67
# Epoch   800, train loss 0.218963, train error 8.00,  test loss 6.643636, test error 57.95
# Epoch   900, train loss 0.220557, train error 8.12,  test loss 7.237449, test error 56.88
# Training model with  45 hidden variables
# Epoch     0, train loss 2.070412, train error 77.05,  test loss 2.013993, test error 77.22
# Epoch   100, train loss 0.804094, train error 25.97,  test loss 1.490475, test error 50.25
# Epoch   200, train loss 0.470282, train error 14.30,  test loss 2.227833, test error 52.47
# Epoch   300, train loss 0.328463, train error 10.55,  test loss 3.329503, test error 53.95
# Epoch   400, train loss 0.229934, train error 7.78,  test loss 4.675171, test error 55.67
# Epoch   500, train loss 0.161086, train error 4.97,  test loss 6.005105, test error 56.62
# Epoch   600, train loss 0.159786, train error 5.75,  test loss 7.266826, test error 57.15
# Epoch   700, train loss 0.108522, train error 3.62,  test loss 8.123290, test error 55.38
# Epoch   800, train loss 0.008458, train error 0.00,  test loss 8.985991, test error 55.60
# Epoch   900, train loss 0.004914, train error 0.00,  test loss 9.512895, test error 55.70
# Training model with  50 hidden variables
# Epoch     0, train loss 2.071181, train error 76.38,  test loss 2.008235, test error 75.50
# Epoch   100, train loss 0.734406, train error 22.82,  test loss 1.623980, test error 49.45
# Epoch   200, train loss 0.319521, train error 8.85,  test loss 2.614163, test error 52.62
# Epoch   300, train loss 0.104506, train error 1.47,  test loss 4.244765, test error 53.35
# Epoch   400, train loss 0.025751, train error 0.00,  test loss 5.719327, test error 54.03
# Epoch   500, train loss 0.011659, train error 0.00,  test loss 6.554173, test error 53.65
# Epoch   600, train loss 0.007523, train error 0.00,  test loss 7.124138, test error 53.67
# Epoch   700, train loss 0.005426, train error 0.00,  test loss 7.563818, test error 53.97
# Epoch   800, train loss 0.004242, train error 0.00,  test loss 7.932702, test error 54.17
# Epoch   900, train loss 0.003408, train error 0.00,  test loss 8.213948, test error 54.10
# Training model with  55 hidden variables
# Epoch     0, train loss 2.092648, train error 77.75,  test loss 2.061226, test error 77.12
# Epoch   100, train loss 0.628128, train error 18.75,  test loss 1.726856, test error 52.28
# Epoch   200, train loss 0.201089, train error 4.05,  test loss 3.202424, test error 54.97
# Epoch   300, train loss 0.035210, train error 0.03,  test loss 4.962904, test error 56.05
# Epoch   400, train loss 0.013213, train error 0.00,  test loss 5.954380, test error 55.78
# Epoch   500, train loss 0.007832, train error 0.00,  test loss 6.574236, test error 56.28
# Epoch   600, train loss 0.005382, train error 0.00,  test loss 7.007952, test error 56.05
# Epoch   700, train loss 0.004092, train error 0.00,  test loss 7.347746, test error 56.05
# Epoch   800, train loss 0.003239, train error 0.00,  test loss 7.621768, test error 56.12
# Epoch   900, train loss 0.002662, train error 0.00,  test loss 7.863176, test error 56.20
# Training model with  60 hidden variables
# Epoch     0, train loss 2.066558, train error 76.88,  test loss 2.021696, test error 76.55
# Epoch   100, train loss 0.525315, train error 14.95,  test loss 1.738742, test error 50.42
# Epoch   200, train loss 0.104274, train error 0.80,  test loss 3.336631, test error 53.70
# Epoch   300, train loss 0.021796, train error 0.00,  test loss 4.729714, test error 54.42
# Epoch   400, train loss 0.009944, train error 0.00,  test loss 5.465235, test error 54.65
# Epoch   500, train loss 0.006168, train error 0.00,  test loss 5.935697, test error 54.72
# Epoch   600, train loss 0.004377, train error 0.00,  test loss 6.278827, test error 54.85
# Epoch   700, train loss 0.003351, train error 0.00,  test loss 6.550154, test error 54.88
# Epoch   800, train loss 0.002688, train error 0.00,  test loss 6.776221, test error 54.70
# Epoch   900, train loss 0.002216, train error 0.00,  test loss 6.963995, test error 54.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.069587, train error 77.22,  test loss 2.032921, test error 75.53
# Epoch   100, train loss 0.351486, train error 8.57,  test loss 1.856529, test error 50.50
# Epoch   200, train loss 0.034670, train error 0.00,  test loss 3.452484, test error 52.85
# Epoch   300, train loss 0.011247, train error 0.00,  test loss 4.217957, test error 52.95
# Epoch   400, train loss 0.006090, train error 0.00,  test loss 4.656463, test error 52.97
# Epoch   500, train loss 0.004105, train error 0.00,  test loss 4.958508, test error 52.90
# Epoch   600, train loss 0.003046, train error 0.00,  test loss 5.183137, test error 52.88
# Epoch   700, train loss 0.002390, train error 0.00,  test loss 5.368570, test error 52.88
# Epoch   800, train loss 0.001949, train error 0.00,  test loss 5.519876, test error 52.85
# Epoch   900, train loss 0.001638, train error 0.00,  test loss 5.651331, test error 52.83
# Training model with  80 hidden variables
# Epoch     0, train loss 2.039480, train error 75.07,  test loss 1.994597, test error 75.07
# Epoch   100, train loss 0.256267, train error 5.30,  test loss 2.072904, test error 51.28
# Epoch   200, train loss 0.020201, train error 0.00,  test loss 3.382936, test error 52.03
# Epoch   300, train loss 0.008006, train error 0.00,  test loss 3.914928, test error 52.47
# Epoch   400, train loss 0.004723, train error 0.00,  test loss 4.232003, test error 52.28
# Epoch   500, train loss 0.003255, train error 0.00,  test loss 4.454795, test error 52.28
# Epoch   600, train loss 0.002447, train error 0.00,  test loss 4.628205, test error 52.12
# Epoch   700, train loss 0.001943, train error 0.00,  test loss 4.771330, test error 52.25
# Epoch   800, train loss 0.001599, train error 0.00,  test loss 4.890624, test error 52.17
# Epoch   900, train loss 0.001352, train error 0.00,  test loss 4.993785, test error 52.12
# Training model with  90 hidden variables
# Epoch     0, train loss 2.051880, train error 76.22,  test loss 2.014673, test error 76.45
# Epoch   100, train loss 0.145598, train error 0.90,  test loss 2.167527, test error 51.72
# Epoch   200, train loss 0.015285, train error 0.00,  test loss 3.169663, test error 52.40
# Epoch   300, train loss 0.006700, train error 0.00,  test loss 3.598589, test error 52.20
# Epoch   400, train loss 0.004104, train error 0.00,  test loss 3.860527, test error 52.30
# Epoch   500, train loss 0.002875, train error 0.00,  test loss 4.045796, test error 52.28
# Epoch   600, train loss 0.002184, train error 0.00,  test loss 4.192396, test error 52.15
# Epoch   700, train loss 0.001745, train error 0.00,  test loss 4.313484, test error 52.15
# Epoch   800, train loss 0.001445, train error 0.00,  test loss 4.415344, test error 52.10
# Epoch   900, train loss 0.001227, train error 0.00,  test loss 4.504591, test error 52.12
# Training model with 100 hidden variables
# Epoch     0, train loss 2.006602, train error 74.80,  test loss 1.930520, test error 74.40
# Epoch   100, train loss 0.100857, train error 0.28,  test loss 2.145741, test error 49.42
# Epoch   200, train loss 0.012789, train error 0.00,  test loss 3.025682, test error 50.17
# Epoch   300, train loss 0.005836, train error 0.00,  test loss 3.394815, test error 50.38
# Epoch   400, train loss 0.003631, train error 0.00,  test loss 3.618681, test error 50.20
# Epoch   500, train loss 0.002572, train error 0.00,  test loss 3.786494, test error 50.25
# Epoch   600, train loss 0.001965, train error 0.00,  test loss 3.913712, test error 50.10
# Epoch   700, train loss 0.001578, train error 0.00,  test loss 4.018581, test error 50.05
# Epoch   800, train loss 0.001309, train error 0.00,  test loss 4.107549, test error 50.05
# Epoch   900, train loss 0.001114, train error 0.00,  test loss 4.185251, test error 50.03
# Training model with 120 hidden variables
# Epoch     0, train loss 1.976459, train error 73.07,  test loss 1.903942, test error 72.88
# Epoch   100, train loss 0.046159, train error 0.00,  test loss 2.253170, test error 50.55
# Epoch   200, train loss 0.009121, train error 0.00,  test loss 2.858823, test error 50.30
# Epoch   300, train loss 0.004587, train error 0.00,  test loss 3.142622, test error 50.28
# Epoch   400, train loss 0.002926, train error 0.00,  test loss 3.325483, test error 50.47
# Epoch   500, train loss 0.002112, train error 0.00,  test loss 3.460120, test error 50.47
# Epoch   600, train loss 0.001634, train error 0.00,  test loss 3.567379, test error 50.58
# Epoch   700, train loss 0.001322, train error 0.00,  test loss 3.656745, test error 50.58
# Epoch   800, train loss 0.001104, train error 0.00,  test loss 3.732274, test error 50.58
# Epoch   900, train loss 0.000945, train error 0.00,  test loss 3.798417, test error 50.58
# Training model with 140 hidden variables
# Epoch     0, train loss 1.978005, train error 72.95,  test loss 1.902278, test error 73.35
# Epoch   100, train loss 0.038048, train error 0.00,  test loss 2.118644, test error 49.42
# Epoch   200, train loss 0.008249, train error 0.00,  test loss 2.596130, test error 49.33
# Epoch   300, train loss 0.004200, train error 0.00,  test loss 2.827638, test error 49.53
# Epoch   400, train loss 0.002728, train error 0.00,  test loss 2.975304, test error 49.53
# Epoch   500, train loss 0.001980, train error 0.00,  test loss 3.087194, test error 49.58
# Epoch   600, train loss 0.001537, train error 0.00,  test loss 3.173754, test error 49.47
# Epoch   700, train loss 0.001247, train error 0.00,  test loss 3.246537, test error 49.47
# Epoch   800, train loss 0.001043, train error 0.00,  test loss 3.309274, test error 49.53
# Epoch   900, train loss 0.000893, train error 0.00,  test loss 3.362849, test error 49.38
# Training model with 160 hidden variables
# Epoch     0, train loss 1.931087, train error 70.55,  test loss 1.868842, test error 72.25
# Epoch   100, train loss 0.028814, train error 0.00,  test loss 2.076813, test error 48.38
# Epoch   200, train loss 0.007167, train error 0.00,  test loss 2.478512, test error 48.30
# Epoch   300, train loss 0.003781, train error 0.00,  test loss 2.679789, test error 48.40
# Epoch   400, train loss 0.002480, train error 0.00,  test loss 2.811409, test error 48.33
# Epoch   500, train loss 0.001817, train error 0.00,  test loss 2.910557, test error 48.28
# Epoch   600, train loss 0.001417, train error 0.00,  test loss 2.990171, test error 48.22
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.054964, test error 48.22
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.111403, test error 48.15
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.161315, test error 48.17
# Training model with 180 hidden variables
# Epoch     0, train loss 1.927114, train error 71.20,  test loss 1.874919, test error 72.68
# Epoch   100, train loss 0.024712, train error 0.00,  test loss 2.092670, test error 49.38
# Epoch   200, train loss 0.006573, train error 0.00,  test loss 2.453361, test error 49.05
# Epoch   300, train loss 0.003520, train error 0.00,  test loss 2.637205, test error 48.90
# Epoch   400, train loss 0.002332, train error 0.00,  test loss 2.758573, test error 48.83
# Epoch   500, train loss 0.001714, train error 0.00,  test loss 2.851852, test error 48.85
# Epoch   600, train loss 0.001342, train error 0.00,  test loss 2.925636, test error 48.88
# Epoch   700, train loss 0.001095, train error 0.00,  test loss 2.987547, test error 48.90
# Epoch   800, train loss 0.000921, train error 0.00,  test loss 3.040554, test error 49.00
# Epoch   900, train loss 0.000791, train error 0.00,  test loss 3.086759, test error 48.95
# Training model with 200 hidden variables
# Epoch     0, train loss 1.907337, train error 68.97,  test loss 1.841831, test error 71.10
# Epoch   100, train loss 0.021394, train error 0.00,  test loss 2.015284, test error 49.38
# Epoch   200, train loss 0.006124, train error 0.00,  test loss 2.319081, test error 49.15
# Epoch   300, train loss 0.003326, train error 0.00,  test loss 2.475722, test error 49.08
# Epoch   400, train loss 0.002222, train error 0.00,  test loss 2.582741, test error 49.30
# Epoch   500, train loss 0.001640, train error 0.00,  test loss 2.663280, test error 49.17
# Epoch   600, train loss 0.001288, train error 0.00,  test loss 2.728518, test error 49.20
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.783443, test error 49.30
# Epoch   800, train loss 0.000887, train error 0.00,  test loss 2.830458, test error 49.33
# Epoch   900, train loss 0.000763, train error 0.00,  test loss 2.871619, test error 49.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.877586, train error 68.45,  test loss 1.795641, test error 69.05
# Epoch   100, train loss 0.017141, train error 0.00,  test loss 1.944860, test error 47.05
# Epoch   200, train loss 0.005352, train error 0.00,  test loss 2.204806, test error 47.22
# Epoch   300, train loss 0.002977, train error 0.00,  test loss 2.344020, test error 47.00
# Epoch   400, train loss 0.002007, train error 0.00,  test loss 2.439363, test error 47.10
# Epoch   500, train loss 0.001492, train error 0.00,  test loss 2.510139, test error 47.00
# Epoch   600, train loss 0.001176, train error 0.00,  test loss 2.568100, test error 47.05
# Epoch   700, train loss 0.000965, train error 0.00,  test loss 2.616569, test error 47.10
# Epoch   800, train loss 0.000815, train error 0.00,  test loss 2.657705, test error 47.05
# Epoch   900, train loss 0.000703, train error 0.00,  test loss 2.694344, test error 47.08
# Training model with 300 hidden variables
# Epoch     0, train loss 1.869559, train error 67.57,  test loss 1.807534, test error 71.47
# Epoch   100, train loss 0.014702, train error 0.00,  test loss 1.845458, test error 46.58
# Epoch   200, train loss 0.004886, train error 0.00,  test loss 2.064787, test error 46.17
# Epoch   300, train loss 0.002763, train error 0.00,  test loss 2.182076, test error 46.10
# Epoch   400, train loss 0.001881, train error 0.00,  test loss 2.263783, test error 46.12
# Epoch   500, train loss 0.001407, train error 0.00,  test loss 2.326004, test error 46.15
# Epoch   600, train loss 0.001114, train error 0.00,  test loss 2.376076, test error 46.20
# Epoch   700, train loss 0.000917, train error 0.00,  test loss 2.418472, test error 46.22
# Epoch   800, train loss 0.000775, train error 0.00,  test loss 2.454395, test error 46.20
# Epoch   900, train loss 0.000670, train error 0.00,  test loss 2.486288, test error 46.15
# Training model with 400 hidden variables
# Epoch     0, train loss 1.823189, train error 65.03,  test loss 1.732747, test error 66.80
# Epoch   100, train loss 0.011643, train error 0.00,  test loss 1.757332, test error 46.25
# Epoch   200, train loss 0.004162, train error 0.00,  test loss 1.933165, test error 46.47
# Epoch   300, train loss 0.002413, train error 0.00,  test loss 2.029912, test error 46.38
# Epoch   400, train loss 0.001663, train error 0.00,  test loss 2.097786, test error 46.33
# Epoch   500, train loss 0.001254, train error 0.00,  test loss 2.150057, test error 46.25
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.192103, test error 46.22
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.228351, test error 46.33
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.259202, test error 46.35
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.286095, test error 46.30

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()

# %%
idx_min_error = np.argmin(errors_test_all)
print(f"min test error achieved {hidden_variables[idx_min_error]} hidden variables")
# Out:
# min test error achieved 8 hidden variables

# %%
offset = 2   # ignore first maximum
idx_max_error = np.argmax(errors_test_all[offset:])
print(f"max test error achieved {hidden_variables[idx_max_error + offset]} hidden variables")
# Out:
# max test error achieved 40 hidden variables

# %% [markdown]
# ##### Conclusion
#
# Prediction was inncorrect due to incorrect parameters count approximation.

# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    self.relu = nn.ReLU()
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x: torch.Tensor) -> torch.Tensor:
    x = self.linear1(x)
    h1: torch.Tensor = self.linear2(x.relu()) + x
    h2: torch.Tensor = self.linear3(h1.relu()) + h1
    h3: torch.Tensor = self.linear4(h2)

    return h3

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(D_i, D_o)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.630996, train error 59.08,  val loss 1.796366, percent error 65.60
# Epoch     1, train loss 1.182998, train error 46.03,  val loss 1.337096, percent error 51.20
# Epoch     2, train loss 0.944539, train error 36.70,  val loss 1.130059, percent error 44.00
# Epoch     3, train loss 0.857092, train error 32.80,  val loss 1.123063, percent error 43.90
# Epoch     4, train loss 0.899641, train error 34.90,  val loss 1.167500, percent error 43.20
# Epoch     5, train loss 0.716780, train error 26.95,  val loss 1.093162, percent error 39.70
# Epoch     6, train loss 0.641260, train error 24.82,  val loss 1.103052, percent error 38.80
# Epoch     7, train loss 0.662177, train error 25.12,  val loss 1.129950, percent error 39.20
# Epoch     8, train loss 0.503027, train error 18.57,  val loss 1.041335, percent error 36.30
# Epoch     9, train loss 0.489987, train error 18.72,  val loss 1.149680, percent error 37.50
# Epoch    10, train loss 0.521038, train error 19.72,  val loss 1.259874, percent error 37.80
# Epoch    11, train loss 0.488393, train error 18.50,  val loss 1.246418, percent error 35.70
# Epoch    12, train loss 0.390719, train error 14.65,  val loss 1.167262, percent error 34.90
# Epoch    13, train loss 0.407677, train error 16.03,  val loss 1.246915, percent error 36.80
# Epoch    14, train loss 0.366973, train error 13.78,  val loss 1.235099, percent error 35.10
# Epoch    15, train loss 0.319447, train error 12.15,  val loss 1.256884, percent error 34.80
# Epoch    16, train loss 0.442800, train error 14.88,  val loss 1.507142, percent error 35.90
# Epoch    17, train loss 0.327946, train error 11.78,  val loss 1.426146, percent error 34.50
# Epoch    18, train loss 0.234226, train error 8.28,  val loss 1.328508, percent error 31.90
# Epoch    19, train loss 0.317325, train error 10.80,  val loss 1.515684, percent error 34.70
# Epoch    20, train loss 0.065929, train error 1.65,  val loss 1.208878, percent error 29.60
# Epoch    21, train loss 0.033708, train error 0.22,  val loss 1.191703, percent error 28.30
# Epoch    22, train loss 0.019404, train error 0.05,  val loss 1.190900, percent error 27.80
# Epoch    23, train loss 0.013174, train error 0.00,  val loss 1.222569, percent error 27.70
# Epoch    24, train loss 0.010498, train error 0.00,  val loss 1.240998, percent error 27.40
# Epoch    25, train loss 0.008959, train error 0.00,  val loss 1.267231, percent error 27.90
# Epoch    26, train loss 0.007889, train error 0.00,  val loss 1.288393, percent error 28.10
# Epoch    27, train loss 0.006993, train error 0.00,  val loss 1.312026, percent error 28.60
# Epoch    28, train loss 0.006324, train error 0.00,  val loss 1.325280, percent error 28.40
# Epoch    29, train loss 0.005719, train error 0.00,  val loss 1.344767, percent error 28.50
# Epoch    30, train loss 0.005260, train error 0.00,  val loss 1.361142, percent error 28.60
# Epoch    31, train loss 0.004876, train error 0.00,  val loss 1.373641, percent error 28.70
# Epoch    32, train loss 0.004534, train error 0.00,  val loss 1.387044, percent error 28.50
# Epoch    33, train loss 0.004235, train error 0.00,  val loss 1.404604, percent error 28.70
# Epoch    34, train loss 0.003976, train error 0.00,  val loss 1.416142, percent error 28.70
# Epoch    35, train loss 0.003752, train error 0.00,  val loss 1.426198, percent error 29.10
# Epoch    36, train loss 0.003536, train error 0.00,  val loss 1.439833, percent error 28.80
# Epoch    37, train loss 0.003355, train error 0.00,  val loss 1.449428, percent error 29.00
# Epoch    38, train loss 0.003183, train error 0.00,  val loss 1.460813, percent error 28.90
# Epoch    39, train loss 0.003031, train error 0.00,  val loss 1.469108, percent error 28.70
# Epoch    40, train loss 0.002956, train error 0.00,  val loss 1.473957, percent error 29.00
# Epoch    41, train loss 0.002888, train error 0.00,  val loss 1.478379, percent error 28.80
# Epoch    42, train loss 0.002826, train error 0.00,  val loss 1.482363, percent error 28.80
# Epoch    43, train loss 0.002764, train error 0.00,  val loss 1.487057, percent error 28.80
# Epoch    44, train loss 0.002706, train error 0.00,  val loss 1.492263, percent error 28.80
# Epoch    45, train loss 0.002649, train error 0.00,  val loss 1.496350, percent error 28.70
# Epoch    46, train loss 0.002596, train error 0.00,  val loss 1.500372, percent error 28.70
# Epoch    47, train loss 0.002544, train error 0.00,  val loss 1.504392, percent error 28.80
# Epoch    48, train loss 0.002494, train error 0.00,  val loss 1.508750, percent error 28.80
# Epoch    49, train loss 0.002446, train error 0.00,  val loss 1.511580, percent error 28.90
# Epoch    50, train loss 0.002399, train error 0.00,  val loss 1.516784, percent error 28.90
# Epoch    51, train loss 0.002355, train error 0.00,  val loss 1.519441, percent error 28.90
# Epoch    52, train loss 0.002311, train error 0.00,  val loss 1.524347, percent error 28.80
# Epoch    53, train loss 0.002270, train error 0.00,  val loss 1.527174, percent error 28.80
# Epoch    54, train loss 0.002229, train error 0.00,  val loss 1.531133, percent error 28.80
# Epoch    55, train loss 0.002191, train error 0.00,  val loss 1.534234, percent error 28.80
# Epoch    56, train loss 0.002154, train error 0.00,  val loss 1.538324, percent error 28.70
# Epoch    57, train loss 0.002117, train error 0.00,  val loss 1.541745, percent error 28.70
# Epoch    58, train loss 0.002082, train error 0.00,  val loss 1.546236, percent error 28.70
# Epoch    59, train loss 0.002047, train error 0.00,  val loss 1.548818, percent error 28.70
# Epoch    60, train loss 0.002030, train error 0.00,  val loss 1.550566, percent error 28.70
# Epoch    61, train loss 0.002014, train error 0.00,  val loss 1.552252, percent error 28.70
# Epoch    62, train loss 0.001997, train error 0.00,  val loss 1.553652, percent error 28.70
# Epoch    63, train loss 0.001982, train error 0.00,  val loss 1.555443, percent error 28.70
# Epoch    64, train loss 0.001966, train error 0.00,  val loss 1.557067, percent error 28.70
# Epoch    65, train loss 0.001951, train error 0.00,  val loss 1.558787, percent error 28.70
# Epoch    66, train loss 0.001936, train error 0.00,  val loss 1.560351, percent error 28.70
# Epoch    67, train loss 0.001921, train error 0.00,  val loss 1.561654, percent error 28.70
# Epoch    68, train loss 0.001906, train error 0.00,  val loss 1.563397, percent error 28.70
# Epoch    69, train loss 0.001892, train error 0.00,  val loss 1.564856, percent error 28.70
# Epoch    70, train loss 0.001877, train error 0.00,  val loss 1.566361, percent error 28.70
# Epoch    71, train loss 0.001863, train error 0.00,  val loss 1.567910, percent error 28.70
# Epoch    72, train loss 0.001849, train error 0.00,  val loss 1.569554, percent error 28.70
# Epoch    73, train loss 0.001836, train error 0.00,  val loss 1.570899, percent error 28.70
# Epoch    74, train loss 0.001822, train error 0.00,  val loss 1.572690, percent error 28.70
# Epoch    75, train loss 0.001809, train error 0.00,  val loss 1.574073, percent error 28.70
# Epoch    76, train loss 0.001796, train error 0.00,  val loss 1.575619, percent error 28.70
# Epoch    77, train loss 0.001783, train error 0.00,  val loss 1.577511, percent error 28.70
# Epoch    78, train loss 0.001770, train error 0.00,  val loss 1.578745, percent error 28.70
# Epoch    79, train loss 0.001758, train error 0.00,  val loss 1.579861, percent error 28.70
# Epoch    80, train loss 0.001751, train error 0.00,  val loss 1.580810, percent error 28.70
# Epoch    81, train loss 0.001745, train error 0.00,  val loss 1.581435, percent error 28.70
# Epoch    82, train loss 0.001739, train error 0.00,  val loss 1.582307, percent error 28.70
# Epoch    83, train loss 0.001733, train error 0.00,  val loss 1.582939, percent error 28.70
# Epoch    84, train loss 0.001727, train error 0.00,  val loss 1.583797, percent error 28.70
# Epoch    85, train loss 0.001721, train error 0.00,  val loss 1.584642, percent error 28.70
# Epoch    86, train loss 0.001715, train error 0.00,  val loss 1.585094, percent error 28.70
# Epoch    87, train loss 0.001709, train error 0.00,  val loss 1.586019, percent error 28.70
# Epoch    88, train loss 0.001703, train error 0.00,  val loss 1.586545, percent error 28.70
# Epoch    89, train loss 0.001697, train error 0.00,  val loss 1.587322, percent error 28.70
# Epoch    90, train loss 0.001691, train error 0.00,  val loss 1.588194, percent error 28.70
# Epoch    91, train loss 0.001685, train error 0.00,  val loss 1.588690, percent error 28.70
# Epoch    92, train loss 0.001680, train error 0.00,  val loss 1.589499, percent error 28.70
# Epoch    93, train loss 0.001674, train error 0.00,  val loss 1.590218, percent error 28.70
# Epoch    94, train loss 0.001668, train error 0.00,  val loss 1.590919, percent error 28.70
# Epoch    95, train loss 0.001663, train error 0.00,  val loss 1.591719, percent error 28.70
# Epoch    96, train loss 0.001657, train error 0.00,  val loss 1.592202, percent error 28.70
# Epoch    97, train loss 0.001652, train error 0.00,  val loss 1.593081, percent error 28.70
# Epoch    98, train loss 0.001646, train error 0.00,  val loss 1.593649, percent error 28.70
# Epoch    99, train loss 0.001641, train error 0.00,  val loss 1.594427, percent error 28.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?

# %%
#Define the model
D_i = 40
D_o = 10
D_h = 100

model = nn.Sequential(
    nn.Linear(D_i, D_h),
    nn.ReLU(),
    nn.Linear(D_h, D_h),
    nn.ReLU(),
    nn.Linear(D_h, D_h),
    nn.ReLU(),
    nn.Linear(D_h, D_o)
)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.619818, train error 61.88,  val loss 1.693600, percent error 66.00
# Epoch     1, train loss 1.344017, train error 51.30,  val loss 1.464463, percent error 58.10
# Epoch     2, train loss 1.187245, train error 45.50,  val loss 1.390398, percent error 54.30
# Epoch     3, train loss 0.970303, train error 35.38,  val loss 1.229897, percent error 47.90
# Epoch     4, train loss 0.865785, train error 31.05,  val loss 1.229906, percent error 45.20
# Epoch     5, train loss 0.806727, train error 29.32,  val loss 1.240681, percent error 44.00
# Epoch     6, train loss 0.698279, train error 25.90,  val loss 1.224111, percent error 43.50
# Epoch     7, train loss 0.544485, train error 18.93,  val loss 1.146223, percent error 40.60
# Epoch     8, train loss 0.451150, train error 15.15,  val loss 1.116025, percent error 38.20
# Epoch     9, train loss 0.448481, train error 16.32,  val loss 1.172527, percent error 38.10
# Epoch    10, train loss 0.402336, train error 14.05,  val loss 1.172796, percent error 38.40
# Epoch    11, train loss 0.319342, train error 11.30,  val loss 1.277823, percent error 39.00
# Epoch    12, train loss 0.276912, train error 9.43,  val loss 1.258075, percent error 37.60
# Epoch    13, train loss 0.295836, train error 11.28,  val loss 1.316981, percent error 37.60
# Epoch    14, train loss 0.185657, train error 5.40,  val loss 1.299894, percent error 36.40
# Epoch    15, train loss 0.237327, train error 8.97,  val loss 1.524151, percent error 38.40
# Epoch    16, train loss 0.149888, train error 5.05,  val loss 1.491692, percent error 37.10
# Epoch    17, train loss 0.102652, train error 2.90,  val loss 1.512578, percent error 35.40
# Epoch    18, train loss 0.126275, train error 4.05,  val loss 1.561651, percent error 37.10
# Epoch    19, train loss 0.157914, train error 5.32,  val loss 1.704935, percent error 37.70
# Epoch    20, train loss 0.031795, train error 0.22,  val loss 1.509649, percent error 33.40
# Epoch    21, train loss 0.017455, train error 0.03,  val loss 1.525869, percent error 34.00
# Epoch    22, train loss 0.011738, train error 0.00,  val loss 1.551916, percent error 34.30
# Epoch    23, train loss 0.009471, train error 0.00,  val loss 1.584207, percent error 33.60
# Epoch    24, train loss 0.008075, train error 0.00,  val loss 1.601902, percent error 33.80
# Epoch    25, train loss 0.007035, train error 0.00,  val loss 1.627757, percent error 33.80
# Epoch    26, train loss 0.006356, train error 0.00,  val loss 1.648862, percent error 33.40
# Epoch    27, train loss 0.005754, train error 0.00,  val loss 1.667327, percent error 33.80
# Epoch    28, train loss 0.005259, train error 0.00,  val loss 1.686085, percent error 33.50
# Epoch    29, train loss 0.004866, train error 0.00,  val loss 1.701272, percent error 33.60
# Epoch    30, train loss 0.004543, train error 0.00,  val loss 1.716692, percent error 33.70
# Epoch    31, train loss 0.004259, train error 0.00,  val loss 1.732643, percent error 33.70
# Epoch    32, train loss 0.003990, train error 0.00,  val loss 1.744567, percent error 33.60
# Epoch    33, train loss 0.003765, train error 0.00,  val loss 1.758174, percent error 33.80
# Epoch    34, train loss 0.003568, train error 0.00,  val loss 1.772412, percent error 33.20
# Epoch    35, train loss 0.003373, train error 0.00,  val loss 1.782669, percent error 33.80
# Epoch    36, train loss 0.003214, train error 0.00,  val loss 1.793122, percent error 33.60
# Epoch    37, train loss 0.003068, train error 0.00,  val loss 1.804916, percent error 33.80
# Epoch    38, train loss 0.002934, train error 0.00,  val loss 1.813817, percent error 33.30
# Epoch    39, train loss 0.002819, train error 0.00,  val loss 1.823410, percent error 33.50
# Epoch    40, train loss 0.002754, train error 0.00,  val loss 1.828997, percent error 33.50
# Epoch    41, train loss 0.002700, train error 0.00,  val loss 1.833256, percent error 33.10
# Epoch    42, train loss 0.002646, train error 0.00,  val loss 1.836718, percent error 33.30
# Epoch    43, train loss 0.002596, train error 0.00,  val loss 1.842092, percent error 33.20
# Epoch    44, train loss 0.002549, train error 0.00,  val loss 1.847304, percent error 33.10
# Epoch    45, train loss 0.002501, train error 0.00,  val loss 1.851195, percent error 33.10
# Epoch    46, train loss 0.002457, train error 0.00,  val loss 1.854645, percent error 33.40
# Epoch    47, train loss 0.002414, train error 0.00,  val loss 1.858436, percent error 33.00
# Epoch    48, train loss 0.002372, train error 0.00,  val loss 1.863693, percent error 33.00
# Epoch    49, train loss 0.002332, train error 0.00,  val loss 1.866921, percent error 33.10
# Epoch    50, train loss 0.002294, train error 0.00,  val loss 1.870960, percent error 32.90
# Epoch    51, train loss 0.002256, train error 0.00,  val loss 1.875435, percent error 33.00
# Epoch    52, train loss 0.002219, train error 0.00,  val loss 1.878296, percent error 33.10
# Epoch    53, train loss 0.002183, train error 0.00,  val loss 1.881941, percent error 33.00
# Epoch    54, train loss 0.002149, train error 0.00,  val loss 1.885795, percent error 33.00
# Epoch    55, train loss 0.002116, train error 0.00,  val loss 1.888800, percent error 33.10
# Epoch    56, train loss 0.002083, train error 0.00,  val loss 1.892008, percent error 33.10
# Epoch    57, train loss 0.002052, train error 0.00,  val loss 1.896320, percent error 33.00
# Epoch    58, train loss 0.002022, train error 0.00,  val loss 1.899851, percent error 33.00
# Epoch    59, train loss 0.001993, train error 0.00,  val loss 1.903838, percent error 33.00
# Epoch    60, train loss 0.001978, train error 0.00,  val loss 1.905088, percent error 33.00
# Epoch    61, train loss 0.001963, train error 0.00,  val loss 1.906693, percent error 33.10
# Epoch    62, train loss 0.001949, train error 0.00,  val loss 1.908293, percent error 33.00
# Epoch    63, train loss 0.001936, train error 0.00,  val loss 1.909918, percent error 33.00
# Epoch    64, train loss 0.001922, train error 0.00,  val loss 1.911453, percent error 33.00
# Epoch    65, train loss 0.001909, train error 0.00,  val loss 1.912915, percent error 32.90
# Epoch    66, train loss 0.001896, train error 0.00,  val loss 1.915453, percent error 32.90
# Epoch    67, train loss 0.001883, train error 0.00,  val loss 1.916174, percent error 32.90
# Epoch    68, train loss 0.001870, train error 0.00,  val loss 1.918170, percent error 32.90
# Epoch    69, train loss 0.001857, train error 0.00,  val loss 1.920283, percent error 33.00
# Epoch    70, train loss 0.001845, train error 0.00,  val loss 1.921726, percent error 32.90
# Epoch    71, train loss 0.001833, train error 0.00,  val loss 1.922957, percent error 32.90
# Epoch    72, train loss 0.001821, train error 0.00,  val loss 1.924548, percent error 32.90
# Epoch    73, train loss 0.001809, train error 0.00,  val loss 1.926300, percent error 33.00
# Epoch    74, train loss 0.001797, train error 0.00,  val loss 1.927990, percent error 32.90
# Epoch    75, train loss 0.001785, train error 0.00,  val loss 1.929505, percent error 32.90
# Epoch    76, train loss 0.001773, train error 0.00,  val loss 1.930736, percent error 32.90
# Epoch    77, train loss 0.001762, train error 0.00,  val loss 1.932427, percent error 32.90
# Epoch    78, train loss 0.001751, train error 0.00,  val loss 1.934345, percent error 32.90
# Epoch    79, train loss 0.001739, train error 0.00,  val loss 1.935576, percent error 32.90
# Epoch    80, train loss 0.001734, train error 0.00,  val loss 1.936163, percent error 32.90
# Epoch    81, train loss 0.001728, train error 0.00,  val loss 1.936908, percent error 32.90
# Epoch    82, train loss 0.001723, train error 0.00,  val loss 1.937790, percent error 32.90
# Epoch    83, train loss 0.001717, train error 0.00,  val loss 1.938624, percent error 32.90
# Epoch    84, train loss 0.001712, train error 0.00,  val loss 1.939318, percent error 32.90
# Epoch    85, train loss 0.001707, train error 0.00,  val loss 1.939937, percent error 33.00
# Epoch    86, train loss 0.001701, train error 0.00,  val loss 1.940589, percent error 32.90
# Epoch    87, train loss 0.001696, train error 0.00,  val loss 1.941473, percent error 32.90
# Epoch    88, train loss 0.001691, train error 0.00,  val loss 1.942339, percent error 32.90
# Epoch    89, train loss 0.001686, train error 0.00,  val loss 1.942929, percent error 32.90
# Epoch    90, train loss 0.001680, train error 0.00,  val loss 1.943801, percent error 32.90
# Epoch    91, train loss 0.001675, train error 0.00,  val loss 1.944453, percent error 33.00
# Epoch    92, train loss 0.001670, train error 0.00,  val loss 1.945104, percent error 32.90
# Epoch    93, train loss 0.001665, train error 0.00,  val loss 1.945805, percent error 33.00
# Epoch    94, train loss 0.001660, train error 0.00,  val loss 1.946728, percent error 32.90
# Epoch    95, train loss 0.001655, train error 0.00,  val loss 1.947331, percent error 32.90
# Epoch    96, train loss 0.001650, train error 0.00,  val loss 1.947911, percent error 32.90
# Epoch    97, train loss 0.001645, train error 0.00,  val loss 1.948732, percent error 32.90
# Epoch    98, train loss 0.001640, train error 0.00,  val loss 1.949599, percent error 32.90
# Epoch    99, train loss 0.001635, train error 0.00,  val loss 1.950129, percent error 33.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# ### Conclusion
#
# Adding residual blocks improved network performance, but it's not as significent change as I expected.

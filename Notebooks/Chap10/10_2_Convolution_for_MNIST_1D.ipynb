# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(in_features=60, out_features=D_o)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.080061, train error 79.50,  val loss 2.080425, percent error 81.30
# Epoch     1, train loss 1.571296, train error 64.40,  val loss 1.591166, percent error 67.10
# Epoch     2, train loss 1.377375, train error 56.05,  val loss 1.386350, percent error 57.60
# Epoch     3, train loss 1.305258, train error 53.47,  val loss 1.349711, percent error 56.90
# Epoch     4, train loss 1.357785, train error 57.47,  val loss 1.369876, percent error 57.60
# Epoch     5, train loss 1.177796, train error 47.97,  val loss 1.220761, percent error 52.40
# Epoch     6, train loss 1.123507, train error 45.45,  val loss 1.178776, percent error 48.70
# Epoch     7, train loss 0.934403, train error 36.17,  val loss 0.979781, percent error 41.30
# Epoch     8, train loss 0.825985, train error 31.82,  val loss 0.899986, percent error 35.40
# Epoch     9, train loss 0.757499, train error 29.88,  val loss 0.852829, percent error 34.00
# Epoch    10, train loss 0.713620, train error 28.35,  val loss 0.801963, percent error 32.00
# Epoch    11, train loss 0.694599, train error 27.72,  val loss 0.802874, percent error 30.30
# Epoch    12, train loss 0.605227, train error 23.32,  val loss 0.727686, percent error 27.50
# Epoch    13, train loss 0.493497, train error 18.55,  val loss 0.622646, percent error 22.70
# Epoch    14, train loss 0.522497, train error 20.10,  val loss 0.649787, percent error 24.70
# Epoch    15, train loss 0.455437, train error 16.70,  val loss 0.591104, percent error 22.30
# Epoch    16, train loss 0.327197, train error 11.55,  val loss 0.487339, percent error 16.00
# Epoch    17, train loss 0.326909, train error 11.62,  val loss 0.481972, percent error 15.90
# Epoch    18, train loss 0.329119, train error 12.07,  val loss 0.496748, percent error 16.10
# Epoch    19, train loss 0.284263, train error 9.78,  val loss 0.425182, percent error 14.30
# Epoch    20, train loss 0.198885, train error 6.62,  val loss 0.361682, percent error 11.80
# Epoch    21, train loss 0.182625, train error 6.38,  val loss 0.364170, percent error 11.50
# Epoch    22, train loss 0.193106, train error 7.22,  val loss 0.373441, percent error 11.60
# Epoch    23, train loss 0.161249, train error 5.47,  val loss 0.369248, percent error 11.60
# Epoch    24, train loss 0.196223, train error 7.18,  val loss 0.385970, percent error 11.80
# Epoch    25, train loss 0.148341, train error 4.82,  val loss 0.362239, percent error 11.60
# Epoch    26, train loss 0.148986, train error 4.93,  val loss 0.348074, percent error 12.20
# Epoch    27, train loss 0.154015, train error 5.12,  val loss 0.352840, percent error 10.70
# Epoch    28, train loss 0.142818, train error 4.95,  val loss 0.364206, percent error 11.20
# Epoch    29, train loss 0.120682, train error 4.12,  val loss 0.358120, percent error 10.30
# Epoch    30, train loss 0.131146, train error 4.65,  val loss 0.372628, percent error 12.00
# Epoch    31, train loss 0.148645, train error 5.70,  val loss 0.366979, percent error 9.90
# Epoch    32, train loss 0.116696, train error 4.12,  val loss 0.377688, percent error 10.50
# Epoch    33, train loss 0.103590, train error 3.45,  val loss 0.347794, percent error 10.80
# Epoch    34, train loss 0.108925, train error 3.72,  val loss 0.360688, percent error 11.00
# Epoch    35, train loss 0.113712, train error 4.00,  val loss 0.384288, percent error 9.70
# Epoch    36, train loss 0.099291, train error 3.55,  val loss 0.363443, percent error 10.90
# Epoch    37, train loss 0.103205, train error 3.57,  val loss 0.388957, percent error 11.30
# Epoch    38, train loss 0.100528, train error 3.40,  val loss 0.371307, percent error 10.50
# Epoch    39, train loss 0.098796, train error 3.32,  val loss 0.390833, percent error 10.30
# Epoch    40, train loss 0.078254, train error 2.30,  val loss 0.369160, percent error 9.60
# Epoch    41, train loss 0.069446, train error 2.03,  val loss 0.369660, percent error 9.80
# Epoch    42, train loss 0.083030, train error 2.62,  val loss 0.375753, percent error 9.40
# Epoch    43, train loss 0.069495, train error 1.95,  val loss 0.358440, percent error 10.30
# Epoch    44, train loss 0.068035, train error 2.03,  val loss 0.364276, percent error 10.30
# Epoch    45, train loss 0.065071, train error 1.80,  val loss 0.364313, percent error 10.30
# Epoch    46, train loss 0.064256, train error 1.80,  val loss 0.367989, percent error 10.10
# Epoch    47, train loss 0.065629, train error 1.93,  val loss 0.372902, percent error 10.40
# Epoch    48, train loss 0.063342, train error 1.75,  val loss 0.384785, percent error 10.90
# Epoch    49, train loss 0.058920, train error 1.72,  val loss 0.369826, percent error 10.50
# Epoch    50, train loss 0.059789, train error 1.72,  val loss 0.375198, percent error 9.70
# Epoch    51, train loss 0.062855, train error 1.82,  val loss 0.397363, percent error 10.40
# Epoch    52, train loss 0.057126, train error 1.65,  val loss 0.386532, percent error 9.60
# Epoch    53, train loss 0.054940, train error 1.85,  val loss 0.389051, percent error 10.50
# Epoch    54, train loss 0.056225, train error 1.57,  val loss 0.386538, percent error 11.20
# Epoch    55, train loss 0.053181, train error 1.62,  val loss 0.395347, percent error 10.30
# Epoch    56, train loss 0.049589, train error 1.28,  val loss 0.390771, percent error 10.30
# Epoch    57, train loss 0.050034, train error 1.22,  val loss 0.386671, percent error 10.40
# Epoch    58, train loss 0.048018, train error 1.20,  val loss 0.406420, percent error 10.30
# Epoch    59, train loss 0.049790, train error 1.25,  val loss 0.411670, percent error 10.30
# Epoch    60, train loss 0.045678, train error 1.25,  val loss 0.397952, percent error 10.50
# Epoch    61, train loss 0.044946, train error 1.15,  val loss 0.398265, percent error 10.20
# Epoch    62, train loss 0.046343, train error 1.12,  val loss 0.400792, percent error 10.40
# Epoch    63, train loss 0.045876, train error 1.25,  val loss 0.405314, percent error 10.30
# Epoch    64, train loss 0.042746, train error 1.05,  val loss 0.408882, percent error 10.80
# Epoch    65, train loss 0.042678, train error 1.03,  val loss 0.408332, percent error 10.40
# Epoch    66, train loss 0.042647, train error 1.03,  val loss 0.406352, percent error 10.80
# Epoch    67, train loss 0.041987, train error 1.03,  val loss 0.403723, percent error 10.10
# Epoch    68, train loss 0.040993, train error 1.00,  val loss 0.411083, percent error 10.60
# Epoch    69, train loss 0.041006, train error 1.00,  val loss 0.416370, percent error 10.90
# Epoch    70, train loss 0.043087, train error 1.18,  val loss 0.421585, percent error 10.50
# Epoch    71, train loss 0.040240, train error 0.90,  val loss 0.416803, percent error 10.90
# Epoch    72, train loss 0.038972, train error 0.85,  val loss 0.414460, percent error 10.30
# Epoch    73, train loss 0.039354, train error 0.93,  val loss 0.411679, percent error 9.90
# Epoch    74, train loss 0.039180, train error 0.90,  val loss 0.420623, percent error 10.70
# Epoch    75, train loss 0.039983, train error 0.93,  val loss 0.422843, percent error 10.90
# Epoch    76, train loss 0.037579, train error 0.90,  val loss 0.423536, percent error 10.70
# Epoch    77, train loss 0.037537, train error 0.90,  val loss 0.420219, percent error 10.60
# Epoch    78, train loss 0.039279, train error 0.95,  val loss 0.429874, percent error 10.30
# Epoch    79, train loss 0.036961, train error 0.75,  val loss 0.427685, percent error 10.40
# Epoch    80, train loss 0.035788, train error 0.60,  val loss 0.424380, percent error 10.20
# Epoch    81, train loss 0.035361, train error 0.80,  val loss 0.424496, percent error 10.60
# Epoch    82, train loss 0.036099, train error 0.80,  val loss 0.429224, percent error 10.60
# Epoch    83, train loss 0.034988, train error 0.75,  val loss 0.424095, percent error 10.40
# Epoch    84, train loss 0.034899, train error 0.72,  val loss 0.428528, percent error 10.50
# Epoch    85, train loss 0.034678, train error 0.70,  val loss 0.428931, percent error 10.80
# Epoch    86, train loss 0.035087, train error 0.72,  val loss 0.429575, percent error 10.70
# Epoch    87, train loss 0.034443, train error 0.72,  val loss 0.429612, percent error 10.70
# Epoch    88, train loss 0.035628, train error 0.72,  val loss 0.433207, percent error 10.40
# Epoch    89, train loss 0.034087, train error 0.72,  val loss 0.430262, percent error 10.60
# Epoch    90, train loss 0.033870, train error 0.65,  val loss 0.431198, percent error 10.50
# Epoch    91, train loss 0.033613, train error 0.55,  val loss 0.433318, percent error 10.30
# Epoch    92, train loss 0.033753, train error 0.60,  val loss 0.431849, percent error 10.00
# Epoch    93, train loss 0.034185, train error 0.65,  val loss 0.436748, percent error 10.70
# Epoch    94, train loss 0.033913, train error 0.62,  val loss 0.436606, percent error 10.50
# Epoch    95, train loss 0.033592, train error 0.55,  val loss 0.436111, percent error 10.00
# Epoch    96, train loss 0.033163, train error 0.57,  val loss 0.437046, percent error 10.40
# Epoch    97, train loss 0.032617, train error 0.57,  val loss 0.437992, percent error 10.60
# Epoch    98, train loss 0.032474, train error 0.57,  val loss 0.438862, percent error 10.30
# Epoch    99, train loss 0.032279, train error 0.50,  val loss 0.438213, percent error 10.70
